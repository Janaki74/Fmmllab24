# %% [markdown]
# <a href="https://colab.research.google.com/github/Janaki74/Fmmllab24/blob/main/Copy_of_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-04 05:04:14--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   141MB/s    in 0.5s
#
# 2025-04-04 05:04:16 (141 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35540   0901.3574v2  Garg and Abadi recently proved that prominent ...    cs
# 8947   1709.09741v1  Effective collaboration between a robot and a ...    cs
# 19712   1109.6030v1  This article develops Probabilistic Hybrid Act...    cs
# 22227  1509.02357v1  We study in this paper the consequences of usi...  stat
# 468    1611.02554v2  We formulate sequence to sequence transduction...    cs
# ...             ...                                                ...   ...
# 23930   1303.6927v1  Image registration is the process of transform...    cs
# 15820  1605.07843v1  In this paper, we develop a novel approach to ...    cs
# 22446  1607.03026v1  We present new methods to estimate causal effe...  stat
# 4488   cs/0403031v2  The human brain has many remarkable informatio...    cs
# 24388   1311.3269v1  In previous works, we investigated the use of ...    cs
#
#                                                    title  year  \
# 35540  Automating Access Control Logics in Simple Typ...  2009
# 8947    WHY: Natural Explanations from a Robot Navigator  2017
# 19712  Probabilistic Hybrid Action Models for Predict...  2011
# 22227  Empirical risk minimization is consistent with...  2015
# 468                             The Neural Noisy Channel  2016
# ...                                                  ...   ...
# 23930  An investigation towards wavelet based optimiz...  2013
# 15820  Unsupervised Word and Dependency Path Embeddin...  2016
# 22446  Retrospective Causal Inference with Machine Le...  2016
# 4488   Concept of E-machine: How does a "dynamical" b...  2004
# 24388  On a non-local spectrogram for denoising one-d...  2013
#
#                                                 keywords
# 35540  [prominent, translated, previously, multimodal...
# 8947   [effective, collaboration, communication, comp...
# 19712  [probabilistic, realistic, predicting, generat...
# 22227  [consequences, percentage, regression, equival...
# 468    [formulate, transduction, recurrent, parameter...
# ...                                                  ...
# 23930  [registration, transforming, different, coordi...
# 15820  [extraction, unsupervised, distributed, repres...
# 22446  [retrospectively, assistance, overcomes, impor...
# 4488   [remarkable, information, processing, characte...
# 24388  [investigated, differential, equations, dimens...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35540    [prominent, translated, previously, multimodal...
# 8947     [effective, collaboration, communication, comp...
# 19712    [probabilistic, realistic, predicting, generat...
# 22227    [consequences, percentage, regression, equival...
# 468      [formulate, transduction, recurrent, parameter...
#                                ...
# 22416    [introduce, correlation, multivariate, nonline...
# 11383    [differentially, algorithms, stochastic, appli...
# 6201     [dimension, reduction, approaches, projections...
# 21551    [notoriously, difficult, dimensional, dimensio...
# 12548    [statistical, protecting, sensitive, informati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8830 words.
# Out of those 4522 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ad0510f5-4c92-40d4-b728-2cfa14dd68ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad0510f5-4c92-40d4-b728-2cfa14dd68ee")) {                    Plotly.newPlot(                        "ad0510f5-4c92-40d4-b728-2cfa14dd68ee",                        [{"x":["previously","multimodal","employing","automating","demonstrated","translated","prominent","different","including","framework","reasoning","embedding","companion","intuitive","decisions","collaboration","cognitively","qualitative","explanations","generation","autonomous","navigates","environment","communication","commonsense","informative","navigation","effective","generated","represent","achievement","conditions","projections","qualitatively","deterministic","concurrent","formalization","descriptions","continuous","processes","contributions","realistic","generates","analytical","represented","probabilistic","structure","inference","efficient","experimental","interferences","predictions","predicting","triggering","consequences","percentage","consistency","equivalent","empirical","universal","minimization","consistent","regression","formulate","summarisation","morphological","conditioning","component","distribution","significantly","abstractive","explaining","recurrent","tractable","outperform","subsequent","transduction","translation","increased","inflection","implement","measurements","intensive","comparison","resulting","efficiently","stochastic","algorithms","competitive","computationally","incorporate","simultaneously","traditionally","performance","important","identification","algorithm","parametric","experiences","outputting","reinforcement","implementation","controller","experience","characterization","monotonic","extending","described","extension","monotonically","characterizations","nonmonotonic","compactness","cumulative","additional","canonical","existence","operation","properties","representations","alternative","assumptions","operations","deductive","characterized","satisfactory","generalizing","complexities","piecewise","following","applications","considers","particular","classifier","dependency","performed","specifically","functions","convergence","switching","partition","partitioning","operating","arbitrary","derivation","generalization","deterministically","rademacher","nonsmooth","decomposition","contributes","hierarchical","denoising","originate","hierarchy","analogous","autoencoder","separation","presented","unsupervised","connections","frameworks","supporting","experiments","variables","autoencoders","invariant","significant","decreases","collectively","techniques","character","combination","identified","translating","topically","statistical","strategies","geographically","resources","normalizing","promising","collected","diversity","normalization","corresponding","established","optimization","restricted","smoothness","convexity","maximization","reminiscent","combinatorial","baselines","estimation","guarantees","submodular","additionally","approximation"],"y":[103,29,30,7,98,23,25,784,249,560,123,100,1,35,70,16,3,75,21,132,52,2,115,75,8,36,28,251,174,112,3,123,26,22,47,7,6,46,101,120,54,67,55,18,81,162,325,193,387,384,2,66,77,5,19,11,53,58,166,41,69,73,124,44,2,26,15,115,212,292,3,20,134,27,115,29,1,118,41,3,63,58,30,134,143,154,125,590,113,96,73,126,17,843,352,93,794,38,11,2,123,129,13,26,27,14,21,60,78,7,4,9,4,12,118,28,32,46,204,254,82,57,69,3,31,15,13,9,12,89,452,29,257,151,48,135,171,214,118,5,25,12,17,90,14,100,4,2,1,67,8,86,48,1,30,13,26,29,180,141,46,30,18,642,113,23,67,237,11,7,378,45,142,28,8,1,176,101,4,72,7,111,63,43,28,136,61,325,53,12,8,30,2,40,57,189,60,16,60,109],"type":"bar"},{"x":["previously","multimodal","employing","automating ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4522,), (4522, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.805

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Visual</span> <span style=''>Graph</span> <span style=''>Mining</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>study</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style=''>mining</span> <span style=''>maximal</span> <span style=''>size</span> <span style=''>frequent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subgraphs</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3746770025839794);'>challenging</span> <span style=''>domain</span> <span style=''>of</span> <span style=''>visual</span> <span style=''>data</span> <span style=''>(images</span> <span style=''>and</span> <span style=''>videos)</span> <span style=''>In</span> <span style=''>general</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0.4008438818565401);'>knowledge</span> <span style=''>can</span> <span style=''>usually</span> <span style=''>be</span> <span style=''>modeled</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>attributed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relational</span> <span style=''>graphs</span> <span style=''>(ARGs)</span> <span style=''>with</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.45631067961165045);'>attributes</span> <span style='background-color:rgba(0, 255, 0, 0.3118279569892473);'>representing</span> <span style=''>local</span> <span style=''>parts</span> <span style=''>and</span> <span style=''>pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.45631067961165045);'>attributes</span> <span style='background-color:rgba(0, 255, 0, 0.4090909090909091);'>describing</span> <span style=''>the</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>parts</span> <span style=''>Thus</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>such</span> <span style=''>mining</span> <span style=''>of</span> <span style=''>maximal</span> <span style=''>size</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subgraphs</span> <span style=''>can</span> <span style=''>be</span> <span style=''>regarded</span> <span style=''>as</span> <span style=''>a</span> <span style=''>general</span> <span style=''>platform</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovering</span> <span style=''>and</span> <span style=''>modeling</span> <span style=''>the</span> <span style=''>common</span> <span style=''>objects</span> <span style=''>within</span> <span style='background-color:rgba(0, 255, 0, 0.875);'>cluttered</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>visual</span> <span style=''>data</span> <span style=''>Then</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>visual</span> <span style=''>graph</span> <span style=''>mining</span> <span style=''>should</span> <span style=''>encode</span> <span style=''>and</span> <span style=''>overcome</span> <span style=''>the</span> <span style=''>great</span> <span style=''>fuzziness</span> <span style=''>of</span> <span style=''>messy</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collected</span> <span style=''>from</span> <span style=''>complex</span> <span style=''>real</span> <span style=''>world</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Iterative</span> <span style=''>Neural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoregressive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimator</span> <span style=''>(NADE</span> <span style=''>k)</span> <br/><br/><span style=''>Training</span> <span style=''>of</span> <span style=''>the</span> <span style=''>neural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>(NADE)</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>doing</span> <span style=''>one</span> <span style=''>step</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>on</span> <span style=''>missing</span> <span style=''>values</span> <span style=''>in</span> <span style=''>data</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>model</span> <span style=''>that</span> <span style=''>extends</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>scheme</span> <span style=''>to</span> <span style=''>multiple</span> <span style=''>steps</span> <span style=''>arguing</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>easier</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>in</span> <span style=''>k</span> <span style=''>steps</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruct</span> <span style=''>in</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>step</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>building</span> <span style=''>block</span> <span style=''>for</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>that</span> <span style=''>combines</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>desirable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>NADE</span> <span style=''>and</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>training</span> <span style=''>(1)</span> <span style=''>Its</span> <span style=''>test</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>can</span> <span style=''>be</span> <span style=''>computed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytically</span> <span style=''>(2)</span> <span style=''>it</span> <span style=''>is</span> <span style=''>easy</span> <span style=''>to</span> <span style=''>generate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>it</span> <span style=''>and</span> <span style=''>(3)</span> <span style=''>it</span> <span style=''>uses</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Binary</span> <span style=''>Bayesian</span> <span style=''>Networks</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Polynomial</span> <span style=''>Time</span> <span style=''>and</span> <span style=''>Sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Complexity</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>learning</span> <span style=''>for</span> <span style=''>binary</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>the</span> <span style=''>true</span> <span style=''>parents</span> <span style=''>and</span> <span style=''>children</span> <span style=''>for</span> <span style=''>each</span> <span style=''>node</span> <span style=''>first</span> <span style=''>and</span> <span style=''>then</span> <span style=''>combine</span> <span style=''>the</span> <span style=''>results</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>the</span> <span style=''>skeleton</span> <span style=''>We</span> <span style=''>do</span> <span style=''>not</span> <span style=''>assume</span> <span style=''>any</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>for</span> <span style=''>the</span> <span style=''>nodes</span> <span style=''>Rather</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>if</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satisfies</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>then</span> <span style=''>we</span> <span style=''>can</span> <span style=''>exactly</span> <span style=''>recover</span> <span style=''>the</span> <span style=''>parents</span> <span style=''>and</span> <span style=''>children</span> <span style=''>of</span> <span style=''>a</span> <span style=''>node</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>l1</span> <span style='background-color:rgba(255, 0, 0, 0.36986301369863017);'>regularized</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.4969574036511155);'>regression</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style=''>number</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>The</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>our</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>depends</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714285);'>logarithmically</span> <span style=''>on</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>our</span> <span style=''>method</span> <span style=''>runs</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Improving</span> <span style=''>accuracy</span> <span style=''>and</span> <span style=''>power</span> <span style=''>with</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>using</span> <span style=''>a</span> <span style=''>meta</span> <span style=''>analytic</span> <span style=''>database</span> <br/><br/><span style=''>Typical</span> <span style=''>cohorts</span> <span style=''>in</span> <span style=''>brain</span> <span style=''>imaging</span> <span style=''>studies</span> <span style=''>are</span> <span style=''>not</span> <span style=''>large</span> <span style=''>enough</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>systematic</span> <span style=''>testing</span> <span style=''>of</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contained</span> <span style=''>in</span> <span style=''>the</span> <span style=''>images</span> <span style=''>To</span> <span style=''>build</span> <span style=''>testable</span> <span style=''>working</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypotheses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigators</span> <span style=''>thus</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>previous</span> <span style=''>work</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sometimes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalized</span> <span style=''>in</span> <span style=''>a</span> <span style=''>so</span> <span style=''>called</span> <span style=''>meta</span> <span style=''>analysis</span> <span style=''>In</span> <span style=''>brain</span> <span style=''>imaging</span> <span style=''>this</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlies</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specification</span> <span style=''>of</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>(ROIs)</span> <span style=''>that</span> <span style=''>are</span> <span style=''>usually</span> <span style=''>selected</span> <span style=''>on</span> <span style=''>the</span> <span style=''>basis</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinates</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style=''>detected</span> <span style=''>effects</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>a</span> <span style=''>database</span> <span style=''>of</span> <span style=''>images</span> <span style=''>rather</span> <span style=''>than</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinates</span> <span style=''>and</span> <span style=''>frame</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>learning</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminant</span> <span style=''>model</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reference</span> <span style=''>task</span> <span style=''>to</span> <span style=''>apply</span> <span style=''>it</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>but</span> <span style=''>related</span> <span style=''>new</span> <span style=''>tas ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.11798152096659559)
# 	segmentation (0.06751954513148543)
# 	evaluation (0.10021321961620469)
# 	information (0.24378109452736318)
# 	architecture (0.08884150675195451)
# 	experimental (0.13646055437100213)
# 	detection (0.12260127931769722)
# 	different (0.27860696517412936)
# 	recognition (0.12544420753375976)
# 	convolutional (0.13503909026297087)
#
# Some Statistics words are:
# 	theoretical (0.14602215508559918)
# 	stochastic (0.1364551863041289)
# 	variables (0.13343403826787512)
# 	statistical (0.16414904330312186)
# 	estimation (0.17220543806646527)
# 	distribution (0.18479355488418933)
# 	dimensional (0.18731117824773413)
# 	algorithm (0.40986908358509566)
# 	inference (0.20241691842900303)
# 	regression (0.18580060422960726)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="31645721-480e-48bc-9c60-450c965a7c0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31645721-480e-48bc-9c60-450c965a7c0c")) {                    Plotly.newPlot(                        "31645721-480e-48bc-9c60-450c965a7c0c",                        [{"x":["previously","multimodal","employing","automating","demonstrated","translated","prominent","different","including","framework","reasoning","embedding","companion","intuitive","decisions","collaboration","cognitively","qualitative","explanations","generation","autonomous","navigates","environment","communication","commonsense","informative","navigation","effective","generated","represent","achievement","conditions","projections","qualitatively","deterministic","concurrent","formalization","descriptions","continuous","processes","contributions","realistic","generates","analytical","represented","probabilistic","structure","inference","efficient","experimental","interferences","predictions","predicting","triggering","consequences","percentage","consistency","equivalent","empirical","universal","minimization","consistent","regression","formulate","summarisation","morphological","conditioning","component","distribution","significantly","abstractive","explaining","recurrent","tractable","outperform","subsequent","transduction","translation","increased","inflection","implement","measurements","intensive","comparison","resulting","efficiently","stochastic","algorithms","competitive","computationally","incorporate","simultaneously","traditionally","performance","important","identification","algorithm","parametric","experiences","outputting","reinforcement","implementation","controller","experience","characterization","monotonic","extending","described","extension","monotonically","characterizations","nonmonotonic","compactness","cumulative","additional","canonical","existence","operation","properties","representations","alternative","assumptions","operations","deductive","characterized","satisfactory","generalizing","complexities","piecewise","following","applications","considers","particular","classifier","dependency","performed","specifically","functions","convergence","switching","partition","partitioning","operating","arbitrary","derivation","generalization","deterministically","rademacher","nonsmooth","decomposition","contributes","hierarchical","denoising","originate","hierarchy","analogous","autoencoder","separation","presented","unsupervised","connections","frameworks","supporting","experiments","variables","autoencoders","invariant","significant","decreases","collectively","techniques","character","combination","identified","translating","topically","statistical","strategies","geographically","resources","normalizing","promising","collected","diversity","normalization","corresponding","established","optimization","restricted","smoothness","convexity","maximization","reminiscent","combinatorial","baselines","estimation","guarantees","submodular","additionally","approximation","classifiers","engineers","internally","repository","currently","evaluation","efficiency","providers","histogram","coefficients","considering","compression","effectiveness","extensive","detection","demonstrate","detecting","comparing","processed","compressed","convolutional","forensics","capability","vulnerable","specifications","definition","probability","expression","misclassification","technique","asymptotic","knowledge","perturbation","transferability","distributions","adversarial","manipulation","intensity","achieving","computational","condition","selection","orthogonal","procedure","hypothesis","extremely","constructing","confidence","negligible","illustrate","screening","statistics","partic ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	internally
# 	predecessors
# 	distilling
# 	couplings
# 	preconditioning
# 	depression
# 	misspecified
# 	covariates
# 	regularizes
# 	criminology
# 	privately
# 	deteriorates
# 	rewritten
# 	physionet
# 	hoeffding
# 	disagreements
# 	recidivism
# 	elliptical
# 	heteroscedasticity
# 	homoscedastic
# Some words which never appear in Statistics papers:
# 	navigates
# 	commonsense
# 	concurrent
# 	interferences
# 	summarisation
# 	abstractive
# 	inflection
# 	nonmonotonic
# 	deductive
# 	operative
# 	endoscopic
# 	wavelength
# 	ontologies
# 	archiving
# 	radiology
# 	connectivities
# 	monocular
# 	insertion
# 	extractive
# 	propositional

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0616618700630706e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7525
