# %% [markdown]
# <a href="https://colab.research.google.com/github/Janaki74/Fmmllab24/blob/main/Module%20_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-04 05:08:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  60.1MB/s    in 1.1s
#
# 2025-04-04 05:08:39 (60.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23286   1012.2603v1  The $\ell_1$ tracker obtains robustness by see...    cs
# 1923   1607.03827v1  Linking human motion and natural language is o...    cs
# 5920    1302.4242v2  Overcomplete representations and dictionary le...    cs
# 35771   1204.3516v1  Quality assurance remains a key topic in human...    cs
# 14437  cs/0008014v1  Data-Oriented Parsing (dop) ranks among the be...    cs
# ...             ...                                                ...   ...
# 6722   1705.08481v2  We study pool-based active learning with abste...  stat
# 19099   1304.1108v1  Scientists often use directed acyclic graphs (...    cs
# 37285  1702.05437v2  With the range and sensitivity of algorithmic ...    cs
# 3885   1508.04467v1  Matrix rank minimizing subject to affine const...    cs
# 24775   1411.6387v2  We consider the problem of depth estimation fr...    cs
#
#                                                    title  year  \
# 23286  Real-time Visual Tracking Using Sparse Represe...  2010
# 1923                     The KIT Motion-Language Dataset  2016
# 5920               Metrics for Multivariate Dictionaries  2013
# 35771  When majority voting fails: Comparing quality ...  2012
# 14437  Aspects of Pattern-Matching in Data-Oriented P...  2000
# ...                                                  ...   ...
# 6722   Bayesian Pool-based Active Learning With Abste...  2017
# 19099                On the Equivalence of Causal Models  2013
# 37285                           Quantifying Program Bias  2017
# 3885   Robust Subspace Clustering via Smoothed Rank A...  2015
# 24775  Deep Convolutional Neural Fields for Depth Est...  2014
#
#                                                 keywords
# 23286  [robustness, representation, minimization, com...
# 1923   [generation, representations, activities, gene...
# 5920   [overcomplete, representations, dictionary, al...
# 35771  [assurance, computation, indicates, effective,...
# 14437  [psycholinguistic, syntactic, structures, gram...
# ...                                                  ...
# 6722   [abstention, feedbacks, abstention, important,...
# 19099  [scientists, qualitative, structure, parameter...
# 37285  [sensitivity, algorithmic, decisions, expandin...
# 3885   [minimizing, constraints, application, process...
# 24775  [estimation, monocular, challenging, available...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23286    [robustness, representation, minimization, com...
# 1923     [generation, representations, activities, gene...
# 5920     [overcomplete, representations, dictionary, al...
# 35771    [assurance, computation, indicates, effective,...
# 14437    [psycholinguistic, syntactic, structures, gram...
#                                ...
# 32879    [approaches, environment, exploring, parameter...
# 7903     [programming, processing, engineering, artific...
# 26470    [reconstruction, binocular, variational, formu...
# 21746    [technique, significantly, alternating, algori...
# 12416    [interface, artificial, intelligence, mathemat...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8883 words.
# Out of those 4562 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="684bca42-bdf7-409c-911e-954ce8468901" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("684bca42-bdf7-409c-911e-954ce8468901")) {                    Plotly.newPlot(                        "684bca42-bdf7-409c-911e-954ce8468901",                        [{"x":["dimensionality","robustness","experimental","reduction","background","exploiting","complexity","sequences","compressed","outperforms","representation","accelerate","comparing","restricts","computational","orthogonal","processing","furthermore","applications","minimization","probability","stationary","customized","integrating","excellence","competitive","meanwhile","algorithms","algorithm","independent","mitigates","evaluation","structure","annotators","represented","selection","therefore","annotation","motivated","resulting","comparable","regardless","specifically","representations","important","activities","thoroughly","development","systematic","excellent","perplexity","annotations","systematically","erroneous","available","aggregate","aforementioned","extensible","databases","generation","standardized","transparent","conducted","properties","assessing","distances","multivariate","interfaces","dictionary","connection","community","perspective","attracting","synthetic","principled","introduce","assessment","grassmannian","dictionaries","underlying","overcomplete","numerically","clustering","theoretically","addresses","competition","recurrent","introduced","manifolds","wasserstein","particular","limitations","statistical","indicates","addressing","significantly","elimination","assurance","computation","effective","comparisons","difficulty","environment","different","tournament","optimizations","efficient","interpret","emphasizing","acceptable","sensitivity","convincingly","retaining","substructures","probabilistic","considerable","structures","construct","necessary","linguistic","possibilities","psycholinguistic","grammatical","derivations","syntactic","proportions","modelling","simultaneously","recognition","initialisation","autoencoders","observations","experiments","unsupervised","performance","application","stochastic","supervised","automatic","unlabelled","classification","techniques","advantage","segmentation","dependencies","dependency","integrate","dependent","variational","framework","inference","processes","nonparametric","dirichlet","information","incorporate","effectiveness","disparate","regression","pediatric","collected","dependence","populations","intensive","disparity","quantified","perceptron","multilayer","institutions","evaluated","mortality","generalization","permutations","investigated","electronic","restoration","navigation","autonomous","dimensional","conditional","monocular","traditional","resolution","differences","detection","unaffected","boundaries","superiority","overcoming","combining","formulate","technique","encountering","translation","additional","generally","advantages","conventional","recommendations","classifier"],"y":[45,81,372,96,79,73,202,96,32,280,374,26,79,4,284,14,288,155,433,61,193,22,5,43,2,116,21,577,783,146,3,241,323,11,75,140,154,58,65,150,95,14,179,245,333,48,10,123,39,33,17,70,18,8,331,17,10,7,50,151,6,6,81,203,14,41,23,13,51,37,89,71,9,126,24,331,40,5,26,111,3,9,145,39,50,24,151,122,15,7,265,51,188,23,28,291,8,4,149,239,41,46,119,752,2,9,393,13,3,14,39,2,11,5,163,45,137,97,83,85,14,3,22,5,46,7,50,91,361,2,26,73,590,135,882,246,130,191,192,3,492,369,97,213,47,54,47,87,54,531,224,101,16,27,730,66,219,7,103,1,76,20,10,26,5,11,22,20,4,142,3,90,5,45,22,19,28,53,179,101,17,176,121,55,366,4,36,34,8,97,49,242,1,119,110,92,79,80,21,147],"type":"bar"},{"x":["dimensionality","robustness","experimental","reduction","background"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4562,), (4562, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Diving</span> <span style=''>deeper</span> <span style=''>into</span> <span style=''>mentee</span> <span style=''>networks</span> <br/><br/><span style=''>Modern</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>is</span> <span style=''>all</span> <span style=''>about</span> <span style=''>the</span> <span style=''>possession</span> <span style=''>of</span> <span style=''>powerful</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.39204545454545453);'>representations</span> <span style=''>Deeper</span> <span style=''>and</span> <span style=''>deeper</span> <span style='background-color:rgba(0, 255, 0, 0.6065573770491803);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>been</span> <span style=''>built</span> <span style=''>using</span> <span style=''>larger</span> <span style=''>and</span> <span style=''>larger</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>are</span> <span style=''>made</span> <span style=''>publicly</span> <span style='background-color:rgba(0, 255, 0, 0.3677685950413223);'>available</span> <span style=''>A</span> <span style=''>large</span> <span style=''>swath</span> <span style=''>of</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scientists</span> <span style=''>use</span> <span style=''>these</span> <span style=''>pre</span> <span style=''>trained</span> <span style=''>networks</span> <span style=''>with</span> <span style=''>varying</span> <span style=''>degrees</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successes</span> <span style=''>in</span> <span style=''>various</span> <span style=''>tasks</span> <span style=''>Even</span> <span style=''>though</span> <span style=''>there</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>tremendous</span> <span style=''>success</span> <span style=''>in</span> <span style=''>copying</span> <span style=''>these</span> <span style=''>networks</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3846153846153846);'>representational</span> <span style=''>space</span> <span style=''>is</span> <span style=''>not</span> <span style=''>learnt</span> <span style=''>from</span> <span style=''>the</span> <span style=''>target</span> <span style=''>dataset</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>traditional</span> <span style=''>manner</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>reasons</span> <span style=''>for</span> <span style=''>opting</span> <span style=''>to</span> <span style=''>use</span> <span style=''>a</span> <span style=''>pre</span> <span style=''>trained</span> <span style=''>network</span> <span style=''>over</span> <span style=''>a</span> <span style=''>network</span> <span style=''>learnt</span> <span style=''>from</span> <span style=''>scratch</span> <span style=''>is</span> <span style=''>that</span> <span style=''>small</span> <span style=''>datasets</span> <span style=''>provide</span> <span style=''>less</span> <span style='background-color:rgba(0, 255, 0, 0.6176470588235294);'>supervision</span> <span style=''>and</span> <span style=''>require</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>meticulous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>smaller</span> <span style=''>and</span> <span style=''>careful</span> <span style=''>tweaking</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>rates</span> <span style=''>to</span> <span style=''>even</span> <span style=''>achieve</span> <span style=''>stable</span> <span style=''>learning</span> <span style=''>without</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style=''>Boundary</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Riemannian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Manifolds</span> <br/><br/><span style=''>We</span> <span style=''>revisit</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>focus</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>For</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>datasets</span> <span style=''>lying</span> <span style=''>on</span> <span style=''>an</span> <span style=''>embedded</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Riemannian</span> <span style=''>manifold</span> <span style=''>within</span> <span style=''>the</span> <span style=''>higher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>space</span> <span style=''>our</span> <span style=''>aim</span> <span style=''>is</span> <span style=''>to</span> <span style=''>acquire</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>boundary</span> <span style=''>between</span> <span style=''>the</span> <span style=''>classes</span> <span style=''>with</span> <span style=''>labels</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Motivated</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style=''>flow</span> <span style=''>Panaretos</span> <span style=''>Pham</span> <span style=''>and</span> <span style=''>Yao</span> <span style=''>2014</span> <span style=''>a</span> <span style=''>curve</span> <span style=''>that</span> <span style=''>moves</span> <span style=''>along</span> <span style=''>a</span> <span style=''>path</span> <span style=''>of</span> <span style=''>the</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style=''>boundary</span> <span style=''>From</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style=''>boundary</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>an</span> <span style=''>optimal</span> <span style=''>curve</span> <span style=''>that</span> <span style=''>moves</span> <span style=''>in</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style=''>flows</span> <span style=''>traced</span> <span style=''>out</span> <span style=''>from</span> <span style=''>two</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>and</span> <span style=''>at</span> <span style=''>any</span> <span style=''>point</span> <span style=''>on</span> <span style=''>the</span> <span style=''>boundary</span> <span style=''>it</span> <span style='backg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Bolasso</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>Lasso</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4482758620689655);'>bootstrap</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>least</span> <span style=''>square</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.5472527472527473);'>regression</span> <span style=''>problem</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>by</span> <span style=''>the</span> <span style=''>l1</span> <span style=''>norm</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>usually</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>detailed</span> <span style='background-color:rgba(255, 0, 0, 0.6448598130841121);'>asymptotic</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>For</span> <span style=''>various</span> <span style=''>decays</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.36807817589576547);'>parameter</span> <span style=''>we</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.6448598130841121);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>equivalents</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>correct</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>(ie</span> <span style=''>variable</span> <span style=''>selection)</span> <span style=''>For</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>rate</span> <span style=''>decay</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Lasso</span> <span style=''>selects</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3947368421052631);'>variables</span> <span style=''>that</span> <span style=''>should</span> <span style=''>enter</span> <span style=''>the</span> <span style=''>model</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>tending</span> <span style=''>to</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponentially</span> <span style=''>fast</span> <span style=''>while</span> <span style=''>it</span> <span style=''>selects</span> <span style=''>all</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3947368421052631);'>variables</span> <span style=''>with</span> <span style=''>strictly</span> <span style=''>positive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style=''>property</span> <span style=''>implies</span> <span style=''>that</span> <span style=''>if</span> <span style=''>we</span> <span style=''>run</span> <span style=''>the ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Overlapping</span> <span style=''>Mixtures</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Association</span> <span style=''>Problem</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>GPs</span> <span style=''>to</span> <span style=''>address</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>problem</span> <span style=''>ie</span> <span style=''>to</span> <span style=''>label</span> <span style=''>a</span> <span style=''>group</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>according</span> <span style=''>to</span> <span style=''>the</span> <span style=''>sources</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>them</span> <span style=''>Unlike</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style=''>proposed</span> <span style=''>GP</span> <span style=''>mixtures</span> <span style=''>the</span> <span style=''>novel</span> <span style=''>mixture</span> <span style=''>has</span> <span style=''>the</span> <span style=''>distinct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristic</span> <span style=''>of</span> <span style=''>using</span> <span style=''>no</span> <span style=''>gating</span> <span style=''>function</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>and</span> <span style=''>mixture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>Instead</span> <span style=''>all</span> <span style=''>the</span> <span style=''>GPs</span> <span style=''>in</span> <span style=''>the</span> <span style=''>mixture</span> <span style=''>are</span> <span style=''>global</span> <span style=''>and</span> <span style=''>samples</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustered</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>across</span> <span style=''>input</span> <span style=''>space</span> <span style=''>We</span> <span style=''>use</span> <span style=''>a</span> <span style=''>non</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>recover</span> <span style=''>sample</span> <span style=''>labels</span> <span style=''>and</span> <span style=''>learn</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>multi</span> <span style=''>object</span> <span style=''>tracking</span> <span style=''>problems</span> <span style=''>can</span> <span style=''>be</span> <span style=''>disambiguated</span> <span style=''>and</span> <span style=''>also</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12781954887218044)
# 	processing (0.10311493018259936)
# 	architecture (0.08879341210168278)
# 	representation (0.13390619405657)
# 	segmentation (0.07626208378088077)
# 	information (0.2613677049767275)
# 	detection (0.1310418904403867)
# 	different (0.26924453992123165)
# 	recognition (0.1292517006802721)
# 	convolutional (0.14035087719298245)
#
# Some Statistics words are:
# 	theoretical (0.1454907822620827)
# 	variables (0.13203786746387644)
# 	statistical (0.15944195316392626)
# 	estimation (0.17040358744394618)
# 	stochastic (0.14598903836571997)
# 	distribution (0.1898355754857997)
# 	inference (0.2012954658694569)
# 	algorithm (0.4020926756352765)
# 	dimensional (0.19133034379671152)
# 	regression (0.1753861484803189)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="67b915bb-9a04-495b-889e-2a8be5c20d45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67b915bb-9a04-495b-889e-2a8be5c20d45")) {                    Plotly.newPlot(                        "67b915bb-9a04-495b-889e-2a8be5c20d45",                        [{"x":["dimensionality","robustness","experimental","reduction","background","exploiting","complexity","sequences","compressed","outperforms","representation","accelerate","comparing","restricts","computational","orthogonal","processing","furthermore","applications","minimization","probability","stationary","customized","integrating","excellence","competitive","meanwhile","algorithms","algorithm","independent","mitigates","evaluation","structure","annotators","represented","selection","therefore","annotation","motivated","resulting","comparable","regardless","specifically","representations","important","activities","thoroughly","development","systematic","excellent","perplexity","annotations","systematically","erroneous","available","aggregate","aforementioned","extensible","databases","generation","standardized","transparent","conducted","properties","assessing","distances","multivariate","interfaces","dictionary","connection","community","perspective","attracting","synthetic","principled","introduce","assessment","grassmannian","dictionaries","underlying","overcomplete","numerically","clustering","theoretically","addresses","competition","recurrent","introduced","manifolds","wasserstein","particular","limitations","statistical","indicates","addressing","significantly","elimination","assurance","computation","effective","comparisons","difficulty","environment","different","tournament","optimizations","efficient","interpret","emphasizing","acceptable","sensitivity","convincingly","retaining","substructures","probabilistic","considerable","structures","construct","necessary","linguistic","possibilities","psycholinguistic","grammatical","derivations","syntactic","proportions","modelling","simultaneously","recognition","initialisation","autoencoders","observations","experiments","unsupervised","performance","application","stochastic","supervised","automatic","unlabelled","classification","techniques","advantage","segmentation","dependencies","dependency","integrate","dependent","variational","framework","inference","processes","nonparametric","dirichlet","information","incorporate","effectiveness","disparate","regression","pediatric","collected","dependence","populations","intensive","disparity","quantified","perceptron","multilayer","institutions","evaluated","mortality","generalization","permutations","investigated","electronic","restoration","navigation","autonomous","dimensional","conditional","monocular","traditional","resolution","differences","detection","unaffected","boundaries","superiority","overcoming","combining","formulate","technique","encountering","translation","additional","generally","advantages","conventional","recommendations","classifier","attention","translations","auxiliary","significant","improvements","consistent","generations","architecture","generated","inadequate","existence","dedicated","illustrates","magnitude","aggregates","extensions","illustrate","satisfiability","straightforward","constraints","unsatisfiability","optimization","considered","responses","posterior","questions","denoising","assumption","estimator","difficult","approaches","cascading","corruption","unavoidable","generative","intractable","corrupted","distribution","tractable","utilization","integrated","extracting","enhancing","convolutional","promotion","benchmark","prediction","experiment","visualization","additionally","discriminator","complementary","motivation","corresponding" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	interpolates
# 	reinterpret
# 	reparametrizations
# 	terabytes
# 	ancillary
# 	semiparametric
# 	uncharted
# 	samplings
# 	schizophrenia
# 	hippocampal
# 	underestimation
# 	interfacing
# 	compensating
# 	exponentiated
# 	penalization
# 	practitioner
# 	sparsities
# 	jackknife
# 	intimately
# 	factorize
# Some words which never appear in Statistics papers:
# 	excellence
# 	attracting
# 	substructures
# 	psycholinguistic
# 	grammatical
# 	monocular
# 	unaffected
# 	generations
# 	satisfiability
# 	unsatisfiability
# 	discourse
# 	controversial
# 	superpixels
# 	curriculum
# 	laborious
# 	proactive
# 	backpropagated
# 	photometric
# 	sentiwordnet
# 	superpixel

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077680659854734e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7783333333333333
